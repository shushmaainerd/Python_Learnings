# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 40.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 33.6 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# np.int64(50)

# %%
int(df['Temperature'].max())
# Out:
# 50

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.shape
# Out:
# (31, 11)

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='str')

# %%
df.dtypes
# Out:
# EST                         str
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn             str
# CloudCover                int64
# Events                      str
# WindDirDegrees            int64
# dtype: object

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     str
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     str
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      str
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), str(3)
# memory usage: 2.8 KB

# %%
df.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df[['Temperature', 'Humidity', 'Events']]
# Out:
#     Temperature  Humidity    Events
# 0            38        52       NaN
# 1            36        46       NaN
# 2            40        47       NaN
# 3            25        44       NaN
# 4            20        41       NaN
# 5            33        35       NaN
# 6            39        33       NaN
# 7            39        64       NaN
# 8            44        77      Rain
# 9            50        71      Rain
# 10           33        37       NaN
# 11           35        53       NaN
# 12           26        42       NaN
# 13           30        47       NaN
# 14           43        62       NaN
# 15           47        70      Rain
# 16           36        66  Fog-Snow
# 17           25        53      Snow
# 18           22        42       NaN
# 19           32        49       NaN
# 20           31        45       NaN
# 21           26        41      Snow
# 22           26        78  Fog-Snow
# 23           28        53      Snow
# 24           34        54       NaN
# ...

# %%
df.iloc[0]        # first row
# Out:
# EST                     1/1/2016
# Temperature                   38
# DewPoint                      23
# Humidity                      52
# Sea Level PressureIn       30.03
# VisibilityMiles               10
# WindSpeedMPH                 8.0
# PrecipitationIn                0
# CloudCover                     5
# Events                       NaN
# WindDirDegrees               281
# Name: 0, dtype: object

# %%
df.iloc[0:5]      # first 5 rows
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.loc[df['Temperature'] > 40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
df[df['Events'] == 'Rain']
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
df[df['Temperature'] < 30]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 12  1/13/2016           26         4        42                 29.94
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 12               10          10.0               0           0       NaN
# ...

# %%
df[(df['Temperature'] < 30) & (df['CloudCover'] >= 5)]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 22  1/23/2016           26        21        78                 29.77
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 22                1          16.0            2.31           8  Fog-Snow
#
#     WindDirDegrees
# 22              42

# %%
df[df['Events'].notna()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# ...

# %%
df['TempCelsius'] = (df['Temperature'] - 32) * 5/9

# %%
float(df['Temperature'].mean())
# Out:
# 34.67741935483871

# %%
float(df['WindSpeedMPH'].max())
# Out:
# 16.0

# %%
df.groupby('Events')['Temperature'].mean()
# Out:
# Events
# Fog-Snow    31.000000
# Rain        45.500000
# Snow        26.333333
# Name: Temperature, dtype: float64

# %%
df.groupby('Events')['Temperature'].mean()
# Out:
# Events
# Fog-Snow    31.000000
# Rain        45.500000
# Snow        26.333333
# Name: Temperature, dtype: float64

# %%
df[['EST', 'Temperature', 'Events']]
# Out:
#           EST  Temperature    Events
# 0    1/1/2016           38       NaN
# 1    1/2/2016           36       NaN
# 2    1/3/2016           40       NaN
# 3    1/4/2016           25       NaN
# 4    1/5/2016           20       NaN
# 5    1/6/2016           33       NaN
# 6    1/7/2016           39       NaN
# 7    1/8/2016           39       NaN
# 8    1/9/2016           44      Rain
# 9   1/10/2016           50      Rain
# 10  1/11/2016           33       NaN
# 11  1/12/2016           35       NaN
# 12  1/13/2016           26       NaN
# 13  1/14/2016           30       NaN
# 14  1/15/2016           43       NaN
# 15  1/16/2016           47      Rain
# 16  1/17/2016           36  Fog-Snow
# 17  1/18/2016           25      Snow
# 18  1/19/2016           22       NaN
# 19  1/20/2016           32       NaN
# 20  1/21/2016           31       NaN
# 21  1/22/2016           26      Snow
# 22  1/23/2016           26  Fog-Snow
# 23  1/24/2016           28      Snow
# ...

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees', 'TempCelsius'],
#       dtype='str')

# %%
df[df['CloudCover']==0]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 12  1/13/2016           26         4        42                 29.94
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  ...  \
# 4                10           5.0               0           0    NaN  ...
# 5                10           4.0               0           0    NaN  ...
# 12               10          10.0               0           0    NaN  ...
# 29               10           7.0               0           0    NaN  ...
# 30               10           5.0               0           0    NaN  ...
#
#     TempCelsius  5  3  1  0  8  7  4  2  6
# 4     -6.666667  0  0  0  0  0  0  0  0  0
# ...

# %%
len(df[df['CloudCover'] == 0])
# Out:
# 5

# %%
float(df['Humidity'].mean())
# Out:
# 51.67741935483871

# %%
df['Humidity'].agg(['mean', 'min', 'max', 'std'])
# Out:
# mean    51.677419
# min     33.000000
# max     78.000000
# std     11.634395
# Name: Humidity, dtype: float64

# %%
df['Events'].str.contains("Snow")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: Events, dtype: bool

# %%
snow_days = df[df['Events'].str.contains("Snow", na=False)]
print(snow_days[['EST', 'Temperature', 'Events']])
# Out:
#           EST  Temperature    Events
# 16  1/17/2016           36  Fog-Snow
# 17  1/18/2016           25      Snow
# 21  1/22/2016           26      Snow
# 22  1/23/2016           26  Fog-Snow
# 23  1/24/2016           28      Snow

# %%
df.columns
# Out:
# Index([                 'EST',          'Temperature',             'DewPoint',
#                    'Humidity', 'Sea Level PressureIn',      'VisibilityMiles',
#                'WindSpeedMPH',      'PrecipitationIn',           'CloudCover',
#                      'Events',       'WindDirDegrees',          'TempCelsius',
#                             5,                      3,                      1,
#                             0,                      8,                      7,
#                             4,                      2,                      6],
#       dtype='object')
