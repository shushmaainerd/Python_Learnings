# %%
import pandas as pd

# %%
df= pd.read_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\stock_data.csv')
df.head(2)
# Out:
#   Datasource: Google finance Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0                    tickers        eps    revenue      price      people
# 1                      GOOGL      27.82         87        845  larry page

# %%
df= pd.read_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\stock_data.csv',skiprows=1)
df.head(2)
# Out:
#   tickers    eps  revenue price      people
# 0   GOOGL  27.82       87   845  larry page
# 1     WMT   4.61      484    65        n.a.

# %%
df= pd.read_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\stock_data.csv',header=1)
df.head(2)
# Out:
#   tickers    eps  revenue price      people
# 0   GOOGL  27.82       87   845  larry page
# 1     WMT   4.61      484    65        n.a.

# %%
df= pd.read_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\stock_data.csv',header=1, names=["Stock_Symbol","eps","revenue","price","people"])
df.head(2)
# Out:
#   Stock_Symbol    eps  revenue price      people
# 0        GOOGL  27.82       87   845  larry page
# 1          WMT   4.61      484    65        n.a.

# %%
df= pd.read_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\stock_data.csv',header=1,nrows=4)
df
# Out:
#   tickers            eps  revenue  price         people
# 0   GOOGL          27.82       87    845     larry page
# 1     WMT           4.61      484     65           n.a.
# 2    MSFT             -1       85     64     bill gates
# 3    RIL   not available       50   1023  mukesh ambani

# %%
df= pd.read_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\stock_data.csv',header=1,na_values={
    'eps':['not available'],
    'revenue':[-1],
    'people':['not available','n.a.']
})
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df = pd.read_csv(
    r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\stock_data.csv',
    header=1,
    na_values=['Not available', 'not available', 'N/A', 'n.a.', -1]
)

# %%
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df["pe"] = df["price"] / df["eps"]
df
# Out:
#   tickers    eps  revenue   price         people         pe
# 0   GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1     WMT   4.61    484.0    65.0            NaN  14.099783
# 2    MSFT    NaN     85.0    64.0     bill gates        NaN
# 3    RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4    TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df.to_csv(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\pe1.csv')

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df_movies = pd.read_excel(
    r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\movies_db.xlsx',
    sheet_name="movies"
)

df_movies.head(3)
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
#
#    release_year  imdb_rating          studio  language_id
# 0          2022          8.4   Hombale Films            3
# 1          2022          7.0  Marvel Studios            5
# 2          2013          6.8  Marvel Studios            5

# %%
df_financials = pd.read_excel(
    r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\movies_db.xlsx',
    sheet_name="financials"
)

df_financials.head(3)
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions       $$

# %%
df_merged = pd.merge(df_movies, df_financials, on="movie_id")
df_merged.head(3)
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
#
#    release_year  imdb_rating          studio  language_id  budget  revenue  \
# 0          2022          8.4   Hombale Films            3     1.0     12.5
# 1          2022          7.0  Marvel Studios            5   200.0    954.8
# 2          2013          6.8  Marvel Studios            5   165.0    644.8
#
#        unit currency
# 0  Billions      INR
# 1  Millions      USD
# 2  Millions       $$

# %%
df_merged.to_excel(r'C:\Users\Shushma Thatipamula\Python_Learnings\Python_Learnings\datasource\movies_merged.xlsx', sheet_name="Sheet1", index=False)

# %%
df_stocks= pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price':[845, 65, 64],
    'pe':[30.45, 14.27, 30.97],
    'eps':[27.82, 4.61, 2.12]
})

# %%
df_stocks
# Out:
#   tickers  price     pe    eps
# 0   GOOGL    845  30.45  27.82
# 1     WMT     65  14.27   4.61
# 2    MSFT     64  30.97   2.12
