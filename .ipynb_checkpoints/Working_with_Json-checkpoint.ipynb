# %%
book={}
book['tom']={
    'name':'tom',
    'address':'1 street,NY',
    'Phone':7786668767
}

book['bob']={
    'name':'bob',
    'address':'1 green st,NY',
    'Phone':774873767
}
import json
s=json.dumps(book)
print(s)
# Out:
# {"tom": {"name": "tom", "address": "1 street,NY", "Phone": 7786668767}, "bob": {"name": "bob", "address": "1 green st,NY", "Phone": 774873767}}

# %%
book={}
book['tom']={
    'name':'tom',
    'address':'1 street,NY',
    'Phone':7786668767
}

book['bob']={
    'name':'bob',
    'address':'1 green st,NY',
    'Phone':774873767
}
import json
s=json.dumps(book)
with open("c://data//book.txt","w") as f:
    f.write(s)

# %%
f=open("c://data//book.txt","r")
s=f.read()
s
# Out:
# '{"tom": {"name": "tom", "address": "1 street,NY", "Phone": 7786668767}, "bob": {"name": "bob", "address": "1 green st,NY", "Phone": 774873767}}'

# %%
import json
book=json.loads(s)
book
# Out:
# {'tom': {'name': 'tom', 'address': '1 street,NY', 'Phone': 7786668767},
#  'bob': {'name': 'bob', 'address': '1 green st,NY', 'Phone': 774873767}}

# %%
type(book)
# Out:
# dict

# %%
book['bob']
# Out:
# {'name': 'bob', 'address': '1 green st,NY', 'Phone': 774873767}

# %%
book['bob']['Phone']
# Out:
# 774873767

# %%
for person in book:
    print(book[person])
# Out:
# {'name': 'tom', 'address': '1 street,NY', 'Phone': 7786668767}
# {'name': 'bob', 'address': '1 green st,NY', 'Phone': 774873767}

# %%
__name__
# Out:
# '__main__'
