# %%
import numpy as np

# %%
arr =np.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr[0][1]
# Out:
# np.int64(2)

# %%
arr[0][2]
# Out:
# np.int64(3)

# %%
arr[1][2]
# Out:
# np.int64(6)

# %%
arr[1,2]
# Out:
# np.int64(6)

# %%
arr_new =np.array([7,8,9])

# %%
arr_new
# Out:
# array([7, 8, 9])

# %%
arr_new[-1]
# Out:
# np.int64(9)

# %%
arr[-1]
# Out:
# array([4, 5, 6])

# %%
arr[1][1]=55

# %%
arr
# Out:
# array([[ 1,  2,  3],
#        [ 4, 55,  6]])

# %%
arr[1]=7
arr
# Out:
# array([[1, 2, 3],
#        [7, 7, 7]])

# %%
arr[0] + 2
# Out:
# array([3, 4, 5])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [7, 7, 7]])
