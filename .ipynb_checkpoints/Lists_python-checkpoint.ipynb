# %%
#lists in Python. If we want to store list of items.Instead of creating more variable for every single item we can use list

# %%
items=["A","B","C","D"]
items
# Out:
# ['A', 'B', 'C', 'D']

# %%
items[0]
# Out:
# 'A'

# %%
items[2]
# Out:
# 'C'

# %%
items[0]='Angie'

# %%
items
# Out:
# ['Angie', 'B', 'C', 'D']

# %%
items[0:]
# Out:
# ['Angie', 'B', 'C', 'D']

# %%
items[:8]
# Out:
# ['Angie', 'B', 'C', 'D']

# %%
items[:2]
# Out:
# ['Angie', 'B']

# %%
items[-1]
# Out:
# 'D'

# %%
items.append("John")

# %%
items
# Out:
# ['Angie', 'B', 'C', 'D', 'John']

# %%
items.insert(1,'Jackson')
items
# Out:
# ['Angie', 'Jackson', 'Jackson', 'Jackson', 'B', 'C', 'D', 'John']

# %%
#You likely ran that same cell several times, so each run added another 'Jackson' at position 1. Jupyter keeps the variable state in memory, so it doesn’t reset items unless you restart the kernel or redefine it.

# %%
food=["pasta","noodels","veggies"]
Bath=["shampoo","Conditioner"]
items= food+Bath
items
# Out:
# ['pasta', 'noodels', 'veggies', 'shampoo', 'Conditioner']

# %%
food+"soda"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 food+"soda"
#
# TypeError: can only concatenate list (not "str") to list

# %%
#Cannot add string or num to string. when adding to string LHS and RHS should be list

# %%
len(items)
# Out:
# 5

# %%
items
# Out:
# ['pasta', 'noodels', 'veggies', 'shampoo', 'Conditioner']

# %%
"bread" in items
# Out:
# False

# %%
"pasta" in items
# Out:
# True

# %%
months = ["jan","Feb","mar","Apr","may"]
values=[2200,2350,2600,2130,2190]
extra= values[1]-values[0]
print("Extra money spent in Feb compared to Jan is", extra)
# Out:
# Extra money spent in Feb compared to Jan is 150

# %%
q1=values[0]+values[1]+values[2]
print("Total expenses in first quarter",q1)
# Out:
# Total expenses in first quarter 7150

# %%
for i in range(len(values)):
    if values[i]==2000:
        print("2000 dollars is spent in ",month[i])
else:
    print("No month spent exaclty 2000 dollars")
# Out:
# No month spent exaclty 2000 dollars

# %%
months.append("June")
values.append(1980)

# %%
months
# Out:
# ['jan', 'Feb', 'mar', 'Apr', 'may', 'June']

# %%
values
# Out:
# [2200, 2350, 2600, 2130, 2190, 1980]

# %%
values[3]=values[3]-200

# %%
values
# Out:
# [2200, 2350, 2600, 1930, 2190, 1980]

# %%
heros=['spider man','thor','hulk','iron man','captain america']
print(len(heros))
# Out:
# 5

# %%
heros.append("Back Panther")

# %%
heros
# Out:
# ['spider man', 'thor', 'hulk', 'iron man', 'captain america', 'Back Panther']

# %%
heros.remove("Back Panther")

# %%
index =heros.index('hulk')
heros.insert(index+1,'Black Panther')
print(heros)
# Out:
# ['spider man', 'thor', 'hulk', 'Black Panther', 'iron man', 'captain america']

# %%
heros
# Out:
# ['spider man', 'thor', 'hulk', 'Black Panther', 'iron man', 'captain america']

# %%
# heros.remove("thor")
# heros.remove("hulk")
# index=heros.index('spider man')
# heros.insert(index+1,'Doctor strange')

heros[1:3]=['Doctor Strange']

# %%
heros
# Out:
# ['spider man',
#  'Doctor Strange',
#  'Black Panther',
#  'iron man',
#  'captain america']

# %%
print(dir(heros))
heros.sort()
print(heros)
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ['Black Panther', 'Doctor Strange', 'captain america', 'iron man', 'spider man']

# %%
# dir() helps you discover methods
# sort() sorts the list in-place
# Sorting is case-sensitive by default
# Use key=str.lower for real-world sorting

heros.sort(key=str.lower)
print(heros)
# Out:
# ['Black Panther', 'captain america', 'Doctor Strange', 'iron man', 'spider man']
