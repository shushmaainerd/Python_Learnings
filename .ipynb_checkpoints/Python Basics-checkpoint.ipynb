# %%
1+1
# Out:
# 2

# %%
1-1
# Out:
# 0

# %%
a=12
b=14
print(a+b)
# Out:
# 26

# %%
nyc_b=188
bal_p=247
Tot_distance = nyc_b+bal_p
Tot_distance
# Out:
# 435

# %%
mph=65
time=Tot_distance/mph
time
# Out:
# 6.6923076923076925

# %%
round(time,2)
# Out:
# 6.69

# %%
round(time,3)
# Out:
# 6.692

# %%
10+2*3 #BODMAS
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %%
6-5.7
# Out:
# 0.2999999999999998

# %%
round(6-5.7,2)
# Out:
# 0.3
