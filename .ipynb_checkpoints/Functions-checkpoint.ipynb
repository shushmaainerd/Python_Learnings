# %%
#function is bock of code that performs actions

# %%
def calcuate_total(exp)
total = 0
for item in exp:
    total=total+item
return total
# Out:
#   Cell In[2], line 1
#     def calcuate_total(exp)
#                            ^
# SyntaxError: expected ':'

# %%
def sum(a,b):
    total=a+b
    return total
n=sum(5,6)
print(n)
# Out:
# 11

# %%
def sum(a,b):
    total=a+b
    return total
n=sum(b=5,a=6) #named arguments
print(n)
# Out:
# 11

# %%
#globas vs loca variables
total=0
def sum(a,b):
    total=a+b
    print("total inside",total)
    return total
n=sum(b=5,a=6) #named arguments
print(total)
# Out:
# total inside 11
# 0

# %%
total=0
def sum(a,b=0):
    total=a+b
    print("total inside",total)
    return total
n=sum(5) #named arguments
print(total)
# Out:
# total inside 5
# 0

# %%
total=0
def sum(a,b=0):
    total=a+b
    print("total inside",total)
    return total
n=sum(5,6) #named arguments
print(total)
# Out:
# total inside 11
# 0

# %%
#Document strings
total=0
def sum(a,b=0):
    """
    Takes two arguments and return sum
    """
    total=a+b
    print("total inside",total)
    return total
n=sum(5,6) #named arguments
print(n)
# Out:
# total inside 11
# 11

# %%
def area(b,h):
    area=(1/2)*b*h
   # print("Area inside", area)
    return area
a=area(3,4)
print("Area outside",a)
# Out:
# Area outside 6.0

# %%
def area(b,h,l):
    area=l*b*h
   # print("Area inside", area)
    return area
a=area(1,3,4)
print("Area outside",a)
# Out:
# Area outside 12
