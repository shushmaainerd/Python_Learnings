# %%
#Hash Table
#I am defining a function to calculate ascii value of cahracter for example ascii value of a is 97

# %%
def get_hash(key):
    h=0
    for char in key:
        h+=ord(char)
    return h % 100

# %%
ord('a')
# Out:
# 97

# %%
class HashTable:
    def __init__(self):
        self.
# Out:
#   Cell In[6], line 1
#     class HashTable:
#                     ^
# SyntaxError: incomplete input
