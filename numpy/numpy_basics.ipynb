# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    ------------------------------ --------- 9.4/12.3 MB 42.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 40.6 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Shushma Thatipamula\Python\envs\py312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import numpy as np

# %%
arr = np.array([1,2,3])

# %%
l=[1,2,3]
l
# Out:
# [1, 2, 3]

# %%
python_list = list(range(100))
python_list[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
#numpy(Numerical Python) array is stored in contigous memory location unlike List in python
#numpy is N dimensional arrays
#core of Numpy is well optimized C

# %%
#Create two list and Add

# %%
import time
start = time.time()
a= [i for i in range(10000000)]
b= [i for i in range(10000000,20000000)]
c=[]
for i in range(len(a)):
    c.append(a[i]*b[i])

print(time.time() - start)
# Out:
# 5.324851036071777

# %%
import numpy as np
start = time.time()
a= np.arange(10000000)
b= np.arange(10000000,20000000)
c=a+b

print(time.time() - start)
# Out:
# 0.6832275390625
