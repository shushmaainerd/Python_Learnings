# %%
import numpy as np
arr= np.array([[1,2,3],[4,5,6]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr[1:]
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr[0:2]
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr[1:2]
# Out:
# array([[4, 5, 6]])

# %%
arr[0:1]
# Out:
# array([[1, 2, 3]])

# %%
arr[0:1,2:3]
# Out:
# array([[3]])
