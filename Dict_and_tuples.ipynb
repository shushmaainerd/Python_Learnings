# %%
d={"Tom":125323,"Rob":6347364,"jon":534254}

# %%
d["Tom"]
# Out:
# 125323

# %%
d["Sam"]=765346543

# %%
d
# Out:
# {'Tom': 125323, 'Rob': 6347364, 'jon': 534254, 'Sam': 765346543}

# %%
#order doesn't matter in dictionary
#how do we delete entry in dictionary

# %%
for key in d:
    print("key:",key,"value:",d[key])
# Out:
# key: Tom value: 125323
# key: Rob value: 6347364
# key: jon value: 534254
# key: Sam value: 765346543

# %%
"Tom" in d
# Out:
# True

# %%
"sammy" in d
# Out:
# False

# %%
#d.clear() will clear the dictionary

# %%
#tuple
#In List All the values have same meaning(Homogeneous)
#Tuple: All the values have different meaning(Heterogeneous)
