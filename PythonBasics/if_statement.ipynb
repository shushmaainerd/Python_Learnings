# %%
num=input("Enter a number:")
num = int(num)
if num%2==0:
    print("Number is even")
else:
    print("number is odd")
# Out:
# Enter a number: 8
# Number is even

# %%
3==3
# Out:
# True

# %%
4!=5
# Out:
# True

# %%
4!=4
# Out:
# False

# %%
3>2 and 4>1
# Out:
# True

# %%
3>2 and 4>5
# Out:
# False

# %%
3>2 or 4>5
# Out:
# True

# %%
not True
# Out:
# False

# %%
not 4 ==4
# Out:
# False

# %%
sports=["Cricket","Football","Hockey"]
IT=["Java developer", "devops", "BI engineer"]

# %%
person=input("Enter profession")
if person in sports:
    print("sports")
elif person in IT:
    print("IT")
else:
    print("other",person)
# Out:
# Enter profession Cricket
# sports
