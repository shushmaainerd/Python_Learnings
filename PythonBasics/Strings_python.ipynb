# %%
text="icecream"

# %%
text[0]
# Out:
# 'i'

# %%
text[5]
# Out:
# 'e'

# %%
text[0]='g' #Strings are immutable. Once created we cannot change. C++, Java Allows but not python
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 text[0]='g'
#
# TypeError: 'str' object does not support item assignment

# %%
text[0:3]
# Out:
# 'ice'

# %%
text[4:9]
# Out:
# 'ream'

# %%
text[3:]
# Out:
# 'cream'

# %%
text[:3]
# Out:
# 'ice'

# %%
text="hello"
text='hello'
text='let's learn python  #problem of using single quote if your textt has aphostophe
# Out:
#   Cell In[12], line 3
#     text='let's learn python
#               ^
# SyntaxError: invalid syntax

# %%
text = "let's learn python"
text
# Out:
# "let's learn python"

# %%
address= "1 pipe street #incorrect syntax
# Out:
#   Cell In[16], line 1
#     address= "1 pipe street
#              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
adress='''1 purple street
newyork
usa'''
print(adress)  #one more way of defining a string
# Out:
# 1 purple street
# newyork
# usa

# %%
adress
# Out:
# '1 purple street\nnewyork\nusa'

# %%
s1="hello"
s2="world"
s1+s2
# Out:
# 'helloworld'

# %%
s1
# Out:
# 'hello'

# %%
s1+' '+s2
# Out:
# 'hello world'

# %%
s="total sales"
num = 25
s+num #python connot add a string with int or non str, so first we have to convert it into str to add
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 s="total sales"
#       2 num = 25
# ----> 3 s+num
#
# TypeError: can only concatenate str (not "int") to str

# %%
str(num)
# Out:
# '25'

# %%
s+str(num)
# Out:
# 'total sales25'
